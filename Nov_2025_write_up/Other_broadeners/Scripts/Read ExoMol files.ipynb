# %%
import pandas as pd
import numpy as np
import os
from glob import iglob

data = pd.read_csv('/Users/elizabeth/Downloads/14N-1H__kNigHt.states.bz2', sep='\s+', header=None)

# %%
data_0s = data[data[10]==0]

# %%
data_j_low = data_0s#[data_0s[3]<=3]

# %%
data_Xmin = data_j_low[data_j_low[9]=='X(3SIGMA-)']

# %%
data_N1 = data_Xmin[data_Xmin[12]==13]

# %%
data_N1

# %%
data_Api = data_0s[data_0s[9]=='A(3PI)']

# %%
data_N2 = data_Api[data_Api[12]==1]

# %%
data_N2

# %%
for line_high in data_N2[1].items():
    for line_low in data_N1[1].items():
        print(line_high[0]+1)
        print(line_low[0]+1)
        print(line_high[1]-line_low[1])
        print('##################')
